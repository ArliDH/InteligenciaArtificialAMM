# %% [markdown]
# **CAR RACING**

# %% [markdown]
# Define un wrapper personalizado para el entorno CarRacing, que analiza los colores del camino y detecta movimiento para modificar la recompensa del agente según la fase, junto con un callback que registra y muestra las recompensas por episodio durante el entrenamiento.

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
import time
import matplotlib.pyplot as plt

class CarRacingRewardWrapper(gym.Wrapper):
    def __init__(self, env, fase=1):
        super().__init__(env)
        self.fase_actual = fase
        self.reset_estadisticas()
        self.episode_count = 0
        
    def reset_estadisticas(self):
        self.pasos_en_verde = 0
        self.pasos_en_gris = 0
        self.ultima_posicion = None
        self.steps_sin_movimiento = 0
        self.total_steps = 0
        self.acciones_positivas = 0
        self.acciones_negativas = 0
        
    def analizar_colores(self, obs):
        try:
            region = obs[70:85, 38:58]
            
            verde_count = 0
            gris_count = 0
            total = max(region.shape[0 ] * region.shape[1], 1)
            
            for i in range(region.shape[0]):
                for j in range(region.shape[1]):
                    r, g, b = region[i, j]
                    r, g, b = int(r), int(g), int(b)
                    
                    diff_rg = abs(r - g)
                    diff_gb = abs(g - b)
                    if diff_rg < 25 and diff_gb < 25 and 90 < r < 120:
                        gris_count += 1
                    elif g > r + 20 and g > b + 20 and g > 95:
                        verde_count += 1
            
            return gris_count / total, verde_count / total
        except:
            return 0.0, 0.0
    
    def detectar_movimiento(self, obs):
        if self.ultima_posicion is None:
            self.ultima_posicion = obs.copy()
            return True
            
        try:
            diff = np.mean(np.abs(obs - self.ultima_posicion))
            self.ultima_posicion = obs.copy()
            return diff > 1.5
        except:
            return True
    
    def step(self, action):
        try:
            obs, reward, terminated, truncated, info = self.env.step(action) 
            self.total_steps += 1
            #estados
            gris_pct, verde_pct = self.analizar_colores(obs)
            se_mueve = self.detectar_movimiento(obs)
            
            custom_reward = 0.0
            
            # SISTEMA DE RECOMPENSAS POR FASE
            if self.fase_actual == 1:
                # FASE 1: RECOMPENSAS SIMPLES Y GENEROSAS
                if se_mueve:
                    custom_reward += 1.0  # Generosa por movimiento
                    self.steps_sin_movimiento = 0
                else:
                    self.steps_sin_movimiento += 1
                    if self.steps_sin_movimiento > 10:
                        custom_reward -= 0.5
                
                if gris_pct > 0.3:  # Umbral bajo
                    custom_reward += 2.0  # Generosa por camino
                    self.pasos_en_gris += 1
                elif verde_pct > 0.25:
                    custom_reward -= 1.0  # Penalización suave
                    
                # Cualquier aceleración es buena en Fase 1
                if action[1] > 0.1:
                    custom_reward += 0.3
                    
            else:
                # FASE 2: RECOMPENSAS MÁS EXIGENTES
                if se_mueve:
                    custom_reward += 0.8  # Menos generosa
                    self.steps_sin_movimiento = 0
                else:
                    self.steps_sin_movimiento += 1
                    if self.steps_sin_movimiento > 8:  # Más exigente
                        custom_reward -= 0.8
                
                if gris_pct > 0.4:  # Umbral más alto
                    custom_reward += 1.5  # Menos generosa
                    self.pasos_en_gris += 1
                    
                    # Bonus por aceleración ÓPTIMA (no cualquier aceleración)
                    if 0.3 < action[1] < 0.7:
                        custom_reward += 0.8
                        
                elif verde_pct > 0.2:  # Más sensible al verde
                    custom_reward -= 1.2  # Penalización más fuerte
                
                # Recompensa por giros SUAVES (no cualquier giro)
                if 0.1 < abs(action[0]) < 0.5:
                    custom_reward += 0.4
            
            # LOGROS (comunes a ambas fases pero con diferentes umbrales)
            if self.fase_actual == 1:
                if self.pasos_en_gris >= 10:  # Fácil en Fase 1
                    custom_reward += 2.0
                    print(f"🏅 FASE 1: ¡Buen comienzo! {self.pasos_en_gris} pasos en gris")
                    self.pasos_en_gris = 0
            else:
                if self.pasos_en_gris >= 20:  # Más difícil en Fase 2
                    custom_reward += 3.0
                    print(f"🏅 FASE 2: ¡Conducción avanzada! {self.pasos_en_gris} pasos en gris")
                    self.pasos_en_gris = 0
            
            # LIMITAR recompensas
            custom_reward = np.clip(custom_reward, -3.0, 3.0).item()
            
            # Mostrar progreso
            if self.total_steps % 100 == 0:
                print(f"📊 Fase {self.fase_actual} - Paso {self.total_steps}: Reward={custom_reward:.1f}")
            
            return obs, float(custom_reward), bool(terminated), bool(truncated), info
            
        except Exception as e:
            print(f"❌ Error en step: {e}")
            return np.zeros((96, 96, 3)), -1.0, True, True, {}
    
    def reset(self, **kwargs):
        self.episode_count += 1
        print(f"\n🔄 FASE {self.fase_actual} - EPISODIO {self.episode_count}")
        self.reset_estadisticas()
        try:
            return self.env.reset(**kwargs)
        except:
            return np.zeros((96, 96, 3)), {}

class VisualizadorCallback(BaseCallback):
    def __init__(self, fase=1, verbose=0):
        super().__init__(verbose)
        self.fase = fase
        self.episodio = 0
        self.recompensa_episodio = 0
        self.mejor_recompensa = -float('inf')
        self.recompensas_por_episodio = []  # Guardar todas las recompensas
    
    def _on_step(self):
        try:
            reward = self.locals['rewards'][0]
            if not np.isnan(reward):
                self.recompensa_episodio += reward
            
            if self.locals['dones'][0]:
                self.episodio += 1
                self.recompensas_por_episodio.append(self.recompensa_episodio)  # Guardar recompensa
                
                if self.recompensa_episodio > self.mejor_recompensa:
                    self.mejor_recompensa = self.recompensa_episodio
                    print(f"🎉 FASE {self.fase} - EPISODIO {self.episodio} - NUEVO RÉCORD: {self.recompensa_episodio:.1f}")
                else:
                    print(f"📊 FASE {self.fase} - EPISODIO {self.episodio} - Recompensa: {self.recompensa_episodio:.1f}")
                
                self.recompensa_episodio = 0
            
            return True
        except:
            return True

# %% [markdown]
# Esta función entrena el modelo PPO en la Fase 1 del entorno CarRacing, usando recompensas generosas para fomentar movimiento y recorrer el camino, registra las recompensas por episodio con un callback, guarda el modelo entrenado y devuelve tanto el modelo como el callback.

# %%
def entrenar_fase_1():
    print("🚀 INICIANDO FASE 1 - EXPLORACIÓN Y APRENDIZAJE BÁSICO")
    
    env = gym.make("CarRacing-v3", render_mode="human", continuous=True)
    env = CarRacingRewardWrapper(env, fase=1)
    
    model = PPO(
        "MlpPolicy",           #  Tipo de red neuronal (Multi-Layer Perceptron)
        env,                   #  Entorno de entrenamiento (CarRacing personalizado)
        verbose=1,             #  Mostrar progreso en consola
        learning_rate=2.5e-4,  #  Velocidad de aprendizaje (0.00025)
        n_steps=2048,          #  Pasos que recolecta antes de aprender
        batch_size=64,         #  Tamaño de cada lote de entrenamiento
        n_epochs=10,           #  Veces que repasa la misma experiencia
        gamma=0.99,            #  Importancia de recompensas futuras
        gae_lambda=0.95,       #  Suavizado de estimaciones de ventaja
        clip_range=0.2,        #  Límite de cambio por actualización (20%)
        ent_coef=0.01,         #  Incentivo para explorar nuevas acciones
        vf_coef=0.5,           #  Estima el valor que tendra un estado si es bueno o malo 
        max_grad_norm=0.8,     #  Límite para gradientes (evita explosión)
        policy_kwargs=dict(
            net_arch=[128, 128] # Arquitectura de red: 2 capas de 128 neuronas , pat basic
        )
    )
    
    callback = VisualizadorCallback(fase=1)
    model.learn(total_timesteps=10000, callback=callback)
    
    model.save("carracing_fase1")
    print("✅ FASE 1 COMPLETADA - Modelo guardado")
    print(f"🏆 Mejor recompensa obtenida: {callback.mejor_recompensa:.1f}")
    print(f"Porcentaje de aprendiza")
    
    env.close()
    return model, callback

# %% [markdown]
# Esta función entrena el modelo PPO en la Fase 2 del entorno CarRacing, utilizando recompensas más exigentes para refinar y optimizar el comportamiento del coche, puede cargar los pesos aprendidos en la Fase 1, registra las recompensas por episodio con un callback, guarda el modelo final y devuelve tanto el modelo como el callback.

# %%
def entrenar_fase_2(modelo_fase1=None):
    print("🚀 INICIANDO FASE 2 - REFINAMIENTO")
    env = gym.make("CarRacing-v3", render_mode="human", continuous=True)
    env = CarRacingRewardWrapper(env, fase=2)
    
    # ⚙️ CONFIGURACIÓN FASE 2
    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        learning_rate=1e-4,      # Más lento para ajustes finos
        n_steps=1024,            # Menos exploración
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.15,
        ent_coef=0.005,          # MENOS exploración
        vf_coef=0.5,
        max_grad_norm=0.6,
        policy_kwargs=dict(
            net_arch=[128, 128]  # Red más grande para patrones complejos
        )
    )
    
    # CARGAR PESOS DE FASE 1 SI EXISTE
    if modelo_fase1 is not None:
        print("🔄 Cargando conocimientos de FASE 1...")
        model.set_parameters(modelo_fase1.get_parameters())
    
    callback = VisualizadorCallback(fase=2)
    print("🏁 COMIENZA FASE 2...")
    model.learn(total_timesteps=15000, callback=callback)
    
    model.save("carracing_fase2")
    print("✅ FASE 2 COMPLETADA - Modelo guardado")
    print(f"🏆 Mejor recompensa obtenida: {callback.mejor_recompensa:.1f}")
    
    env.close()
    return model, callback

# %% [markdown]
# Esta función prueba un modelo entrenado en el entorno CarRacing ejecutando 3 episodios de manera determinista, muestra la interacción del coche en pantalla, acumula la recompensa total y los pasos por episodio, y finalmente cierra el entorno.

# %%
def probar_modelo(fase=2):
        print(f"🎮 PROBANDO MODELO FASE {fase}...")
    
        env = gym.make("CarRacing-v3", render_mode="human", continuous=True)
        env = CarRacingRewardWrapper(env, fase=fase)
    
        model = PPO.load("carracing_fase1" if fase==1 else "carracing_fase2")
            
        print(f"✅ Modelo FASE {fase} cargado")
        
        for episodio in range(3):
            obs, info = env.reset()
            done = False
            total_reward = 0
            pasos = 0
            
            print(f"🏁 EPISODIO PRUEBA {episodio + 1}")
            
            while not done and pasos < 500:
                action, _ = model.predict(obs, deterministic=True)
                obs, reward, terminated, truncated, info = env.step(action)
                total_reward += reward
                pasos += 1
                done = terminated or truncated
                
                time.sleep(0.02)
            
            print(f"🏁 EPISODIO {episodio+1} - Pasos: {pasos} | Recompensa: {total_reward:.1f}")
        
        env.close()

# %% [markdown]
# Esta sección es el programa principal, que al ejecutarse entrena primero la Fase 1 (exploración básica) y luego la Fase 2 (refinamiento), guardando los modelos entrenados y los callbacks asociados para cada fase.

# %%
# 🎮 PROGRAMA PRINCIPAL
if __name__ == "__main__":
    # ENTRENAMIENTO COMPLETO
    modelo_fase1, callback1 = entrenar_fase_1()
    modelo_fase2, callback2 = entrenar_fase_2(modelo_fase1)
# Out:
# 🚀 INICIANDO FASE 1 - EXPLORACIÓN Y APRENDIZAJE BÁSICO
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
#
# 🔄 FASE 1 - EPISODIO 1
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=2.3
#
# 🔄 FASE 1 - EPISODIO 2
# 🎉 FASE 1 - EPISODIO 1 - NUEVO RÉCORD: 2652.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=3.0
#
# 🔄 FASE 1 - EPISODIO 3
# 📊 FASE 1 - EPISODIO 2 - Recompensa: 2628.1
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.64e+03 |
# | time/              |          |
# |    fps             | 25       |
# |    iterations      | 1        |
# |    time_elapsed    | 81       |
# |    total_timesteps | 2048     |
# ---------------------------------
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=3.0
#
# 🔄 FASE 1 - EPISODIO 4
# 🎉 FASE 1 - EPISODIO 3 - NUEVO RÉCORD: 2724.7
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=3.0
#
# 🔄 FASE 1 - EPISODIO 5
# 📊 FASE 1 - EPISODIO 4 - Recompensa: 2677.2
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.67e+03    |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 2           |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010858977 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.00922    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 332         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1.01        |
# |    value_loss           | 935         |
# -----------------------------------------
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=0.3
#
# 🔄 FASE 1 - EPISODIO 6
# 📊 FASE 1 - EPISODIO 5 - Recompensa: 2596.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=3.0
#
# 🔄 FASE 1 - EPISODIO 7
# 🎉 FASE 1 - EPISODIO 6 - NUEVO RÉCORD: 2774.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.68e+03    |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 3           |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014150424 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 502         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 1.01        |
# |    value_loss           | 1.36e+03    |
# -----------------------------------------
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=2.3
#
# 🔄 FASE 1 - EPISODIO 8
# 🎉 FASE 1 - EPISODIO 7 - NUEVO RÉCORD: 2799.9
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=2.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=0.0
# 📊 Fase 1 - Paso 700: Reward=-1.0
# 📊 Fase 1 - Paso 800: Reward=0.0
# 📊 Fase 1 - Paso 900: Reward=0.3
# 📊 Fase 1 - Paso 1000: Reward=-0.7
#
# 🔄 FASE 1 - EPISODIO 9
# 📊 FASE 1 - EPISODIO 8 - Recompensa: 1587.2
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.56e+03    |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 4           |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008378812 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 477         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00419    |
# |    std                  | 1.01        |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=-1.0
#
# 🔄 FASE 1 - EPISODIO 10
# 📊 FASE 1 - EPISODIO 9 - Recompensa: 2658.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 600: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 700: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 800: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 900: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 1000: Reward=3.0
#
# 🔄 FASE 1 - EPISODIO 11
# 🎉 FASE 1 - EPISODIO 10 - NUEVO RÉCORD: 2822.7
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=2.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# ...
# 📊 Fase 2 - Paso 100: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 200: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 9            |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0032359671 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 246          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00281     |
# |    std                  | 1.02         |
# |    value_loss           | 530          |
# ------------------------------------------
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 300: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 400: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 500: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 600: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 700: Reward=0.0
# 📊 Fase 2 - Paso 800: Reward=-0.4
# 📊 Fase 2 - Paso 900: Reward=-0.4
# 📊 Fase 2 - Paso 1000: Reward=-1.2
#
# 🔄 FASE 2 - EPISODIO 11
# 📊 FASE 2 - EPISODIO 10 - Recompensa: 1323.8
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 200: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 10          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004478629 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 279         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -8.55e-05   |
# |    std                  | 1.02        |
# |    value_loss           | 544         |
# -----------------------------------------
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 300: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 400: Reward=-0.4
# 📊 Fase 2 - Paso 500: Reward=-0.4
# 📊 Fase 2 - Paso 600: Reward=-0.4
# 📊 Fase 2 - Paso 700: Reward=-1.2
# 📊 Fase 2 - Paso 800: Reward=0.0
# 📊 Fase 2 - Paso 900: Reward=0.0
# 📊 Fase 2 - Paso 1000: Reward=0.0
#
# 🔄 FASE 2 - EPISODIO 12
# 📊 FASE 2 - EPISODIO 11 - Recompensa: 633.6
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 200: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.02e+03    |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 11          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.001166838 |
# |    clip_fraction        | 0.000781    |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 312         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000181   |
# |    std                  | 1.02        |
# |    value_loss           | 621         |
# -----------------------------------------
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 300: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 400: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 500: Reward=0.0
# 📊 Fase 2 - Paso 600: Reward=-1.2
# 📊 Fase 2 - Paso 700: Reward=-0.4
# 📊 Fase 2 - Paso 800: Reward=0.0
# 📊 Fase 2 - Paso 900: Reward=0.0
# 📊 Fase 2 - Paso 1000: Reward=-1.2
#
# 🔄 FASE 2 - EPISODIO 13
# 📊 FASE 2 - EPISODIO 12 - Recompensa: 825.1
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 200: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.01e+03    |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 12          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004654155 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 223         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.000282    |
# |    std                  | 1.02        |
# |    value_loss           | 489         |
# -----------------------------------------
# 📊 Fase 2 - Paso 300: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 400: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 500: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 600: Reward=-0.4
# 📊 Fase 2 - Paso 700: Reward=-0.4
# 📊 Fase 2 - Paso 800: Reward=-0.4
# 📊 Fase 2 - Paso 900: Reward=-0.4
# 📊 Fase 2 - Paso 1000: Reward=-1.2
#
# 🔄 FASE 2 - EPISODIO 14
# 📊 FASE 2 - EPISODIO 13 - Recompensa: 1198.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 200: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 300: Reward=3.0
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 13           |
# |    time_elapsed         | 510          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0026462877 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 270          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00199     |
# |    std                  | 1.02         |
# |    value_loss           | 582          |
# ------------------------------------------
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 400: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 500: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 600: Reward=-0.4
# 📊 Fase 2 - Paso 700: Reward=0.0
# 📊 Fase 2 - Paso 800: Reward=-0.4
# 📊 Fase 2 - Paso 900: Reward=0.0
# 📊 Fase 2 - Paso 1000: Reward=-0.8
#
# 🔄 FASE 2 - EPISODIO 15
# 📊 FASE 2 - EPISODIO 14 - Recompensa: 1161.8
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 200: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 300: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 14           |
# |    time_elapsed         | 547          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0008760873 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 313          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000141    |
# |    std                  | 1.02         |
# |    value_loss           | 631          |
# ------------------------------------------
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 400: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 500: Reward=0.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 600: Reward=2.7
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 700: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 800: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 900: Reward=2.3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 1000: Reward=2.3
#
# 🔄 FASE 2 - EPISODIO 16
# 📊 FASE 2 - EPISODIO 15 - Recompensa: 2068.6
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris

# %% [markdown]
# Esta parte genera las gráficas de aprendizaje para cada fase: muestra la recompensa acumulada por episodio y marca con un punto rojo el episodio donde se obtuvo la mejor recompensa para la Fase 1 (callback1) y la Fase 2 (callback2).

# %%
# 📊 GRAFICA DE APRENDIZAJE
plt.figure(figsize=(10,5))
plt.plot(callback1.recompensas_por_episodio, label="Recompensa por episodio")
mejor_ep = callback1.recompensas_por_episodio.index(callback1.mejor_recompensa)
plt.scatter(mejor_ep, callback1.mejor_recompensa, color='red', label="Mejor recompensa", zorder=5)
plt.xlabel("Episodio")
plt.ylabel("Recompensa acumulada")
plt.title("Aprendizaje Fase 1")
plt.grid(True)
plt.legend()
plt.show()

# %%
# 📊 GRAFICA DE APRENDIZAJE FASE 2
plt.figure(figsize=(10,5))
plt.plot(callback2.recompensas_por_episodio, label="Recompensa por episodio")
mejor_ep = callback2.recompensas_por_episodio.index(callback2.mejor_recompensa)
plt.scatter(mejor_ep, callback2.mejor_recompensa, color='red', label="Mejor recompensa", zorder=5)
plt.xlabel("Episodio")
plt.ylabel("Recompensa acumulada")
plt.title("Aprendizaje Fase 2")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Aquí se prueba visualmente el modelo entrenado: primero ejecuta 3 episodios de prueba para la Fase 1 y luego 3 episodios para la Fase 2, mostrando en pantalla los pasos y la recompensa acumulada de cada episodio.

# %%
# PRUEBA DEL MODELO
probar_modelo(fase=1)    
probar_modelo(fase=2)
# Out:
# 🎮 PROBANDO MODELO FASE 1...
# ✅ Modelo FASE 1 cargado
#
# 🔄 FASE 1 - EPISODIO 1
# 🏁 EPISODIO PRUEBA 1
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=0.3
# 🏁 EPISODIO 1 - Pasos: 500 | Recompensa: 625.2
#
# 🔄 FASE 1 - EPISODIO 2
# 🏁 EPISODIO PRUEBA 2
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=0.3
# 📊 Fase 1 - Paso 300: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=0.3
# 🏁 EPISODIO 2 - Pasos: 500 | Recompensa: 730.5
#
# 🔄 FASE 1 - EPISODIO 3
# 🏁 EPISODIO PRUEBA 3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 100: Reward=3.0
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 200: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 300: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 400: Reward=0.3
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 🏅 FASE 1: ¡Buen comienzo! 10 pasos en gris
# 📊 Fase 1 - Paso 500: Reward=0.3
# 🏁 EPISODIO 3 - Pasos: 500 | Recompensa: 530.7
# 🎮 PROBANDO MODELO FASE 2...
# ✅ Modelo FASE 2 cargado
#
# 🔄 FASE 2 - EPISODIO 1
# 🏁 EPISODIO PRUEBA 1
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=-0.4
# 📊 Fase 2 - Paso 200: Reward=-0.4
# 🏁 EPISODIO 1 - Pasos: 207 | Recompensa: 151.8
#
# 🔄 FASE 2 - EPISODIO 2
# 🏁 EPISODIO PRUEBA 2
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=3.0
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 200: Reward=-0.4
# 🏁 EPISODIO 2 - Pasos: 202 | Recompensa: 238.8
#
# 🔄 FASE 2 - EPISODIO 3
# 🏁 EPISODIO PRUEBA 3
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 🏅 FASE 2: ¡Conducción avanzada! 20 pasos en gris
# 📊 Fase 2 - Paso 100: Reward=-0.4
# 📊 Fase 2 - Paso 200: Reward=-0.4
# 🏁 EPISODIO 3 - Pasos: 209 | Recompensa: 144.2
